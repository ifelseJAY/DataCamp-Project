# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7e945e00-f9b2-44fa-aa38-7f49254072b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e945e00-f9b2-44fa-aa38-7f49254072b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Global_Retail_Sales Data (2021–2024).csv")
df.head()
# Out:
#    Order_Date Country         City     Category Sub_Category      Segment  \
# 0  2022-06-20     UAE        Dubai    Furniture       Snacks     Consumer
# 1  2023-12-05      UK       London       Sports       Phones  Home Office
# 2  2022-07-05     USA  Los Angeles  Electronics       Shirts     Consumer
# 3  2024-10-05     USA     New York    Furniture       Phones     Consumer
# 4  2023-07-21     USA     New York       Beauty      Fitness     Consumer
#
#   Sales_Channel Payment_Mode    Sales  Quantity  Discount  Profit
# 0       Offline          UPI  2555.49        11      0.08  255.37
# 1        Online  Net Banking  1795.27         9      0.28 -332.23
# 2       Offline          UPI  4554.73        10      0.13  140.24
# 3        Online  Net Banking  3107.15        13      0.14   60.70
# 4       Offline         Card  2781.45        12      0.20   61.78

# %%
df.dtypes
# Out:
# Order_Date        object
# Country           object
# City              object
# Category          object
# Sub_Category      object
# Segment           object
# Sales_Channel     object
# Payment_Mode      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_Date     1600 non-null   object
#  1   Country        1600 non-null   object
#  2   City           1600 non-null   object
#  3   Category       1600 non-null   object
#  4   Sub_Category   1600 non-null   object
#  5   Segment        1600 non-null   object
#  6   Sales_Channel  1600 non-null   object
#  7   Payment_Mode   1600 non-null   object
#  8   Sales          1600 non-null   float64
#  9   Quantity       1600 non-null   int64
#  10  Discount       1600 non-null   float64
#  11  Profit         1600 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 150.1+ KB

# %%
df.describe()
# Out:
#              Sales     Quantity     Discount       Profit
# count  1600.000000  1600.000000  1600.000000  1600.000000
# mean   2527.242200     7.582500     0.147138   244.332881
# std    1410.954469     3.999618     0.085156   515.339896
# min     100.260000     1.000000     0.000000  -937.750000
# 25%    1293.730000     4.000000     0.070000   -88.145000
# 50%    2496.750000     8.000000     0.150000   138.665000
# 75%    3715.987500    11.000000     0.220000   535.817500
# max    4996.120000    14.000000     0.300000  1921.420000

# %%
df.describe(include='object')
# Out:
#         Order_Date Country    City     Category Sub_Category      Segment  \
# count         1600    1600    1600         1600         1600         1600
# unique         963       8      24            6            6            3
# top     2023-12-09   India  Mumbai  Electronics       Chairs  Home Office
# freq             6     227      89          288          295          546
#
#        Sales_Channel Payment_Mode
# count           1600         1600
# unique             2            4
# top          Offline         Card
# freq             817          438

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Sports', 'Electronics', 'Beauty', 'Groceries',
#        'Clothing'], dtype=object)

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai         89
# Montreal       79
# Sharjah        79
# Sydney         76
# Toronto        76
# Bangalore      75
# Dubai          71
# Nice           70
# London         69
# Chicago        69
# Paris          68
# Berlin         67
# Melbourne      67
# Perth          66
# New York       66
# Delhi          63
# Abu Dhabi      61
# Vancouver      61
# Los Angeles    60
# Lyon           58
# Munich         57
# Manchester     56
# Birmingham     49
# Hamburg        48
# Name: count, dtype: int64

# %%
train_data = df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(train_data['Sales'], bins=20,)
counts, bins, patches = plt.hist(train_data['Sales'], bins=20, alpha=0)
for count, patch in zip(counts, patches):
    plt.text(patch.get_x() + patch.get_width() / 2, count, int(count), ha='center', va='bottom')
plt.title("Sales Distribution")
plt.show()

sns.histplot(train_data['Profit'], bins=20,)
counts, bins, patches = plt.hist(train_data['Profit'], bins=20, alpha=0)
for count, patch in zip(counts, patches):
    plt.text(patch.get_x() + patch.get_width() / 2, count, int(count), ha='center', va='bottom')
plt.title("Profit Distribution")
plt.show()

sns.histplot(train_data['Discount'], bins=20,)
counts, bins, patches = plt.hist(train_data['Discount'], bins=20, alpha=0)
for count, patch in zip(counts, patches):
    plt.text(patch.get_x() + patch.get_width() / 2, count, int(count), ha='center', va='bottom')
plt.title("Discount Distribution")
plt.show()

# %%
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title("Sales vs Profit")
plt.show()

sns.scatterplot(x='Discount', y='Profit', data=df)
plt.title("Discount vs Profit")
plt.show()

sns.countplot(x='Segment', hue='Sales_Channel', data=df)
plt.title("Segment vs Sales Channel")
plt.show()

sns.countplot(x='Country', hue='Category', data=df)
plt.title("Category Distribution by Country")
plt.show()

# %%
df.columns
# Out:
# Index(['Order_Date', 'Country', 'City', 'Category', 'Sub_Category', 'Segment',
#        'Sales_Channel', 'Payment_Mode', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
numerical_cols = df.select_dtypes(include=['number'])
display(numerical_cols.head())
# Out:
#      Sales  Quantity  Discount  Profit
# 0  2555.49        11      0.08  255.37
# 1  1795.27         9      0.28 -332.23
# 2  4554.73        10      0.13  140.24
# 3  3107.15        13      0.14   60.70
# 4  2781.45        12      0.20   61.78

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
train_data
# Out:
#       Order_Date    Country         City     Category Sub_Category  \
# 0     2022-06-20        UAE        Dubai    Furniture       Snacks
# 1     2023-12-05         UK       London       Sports       Phones
# 2     2022-07-05        USA  Los Angeles  Electronics       Shirts
# 3     2024-10-05        USA     New York    Furniture       Phones
# 4     2023-07-21        USA     New York       Beauty      Fitness
# ...          ...        ...          ...          ...          ...
# 1595  2023-10-17     Canada      Toronto    Furniture       Snacks
# 1596  2021-04-16     France         Lyon     Clothing      Fitness
# 1597  2021-06-11  Australia       Sydney       Sports    Cosmetics
# 1598  2024-05-21      India       Mumbai  Electronics       Snacks
# 1599  2021-07-25      India    Bangalore  Electronics       Snacks
#
#           Segment Sales_Channel Payment_Mode    Sales  Quantity  Discount  \
# 0        Consumer       Offline          UPI  2555.49        11      0.08
# ...

# %%
x = train_data['Quantity']
y = train_data['Profit']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train)
Predictions = model.predict(x_test.values.reshape(-1, 1))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, Predictions)
mse = mean_squared_error(y_test, Predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, Predictions)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R-squared (R2): {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 384.00
# Mean Squared Error (MSE): 239252.49
# Root Mean Squared Error (RMSE): 489.13
# R-squared (R2): 0.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=Predictions)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual vs. Predicted Profit')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.show()

# %% [markdown]
# ### Data Loading and Initial Inspection
#
# This section covers the initial loading of the dataset and a preliminary inspection of its structure and content.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# In this section, we perform Exploratory Data Analysis to understand the data's characteristics, distributions, and relationships between variables. This includes checking data types, summary statistics, identifying missing values, and visualizing key features.

# %% [markdown]
# #### Distribution of Numerical Features
#
# Histograms are used to visualize the distribution of numerical features such as 'Sales', 'Profit', and 'Discount'.

# %% [markdown]
# #### Relationships Between Numerical Features
#
# Scatter plots help in understanding the relationships between numerical variables, such as 'Sales' vs 'Profit' and 'Discount' vs 'Profit'.

# %% [markdown]
# #### Categorical Feature Analysis
#
# Count plots are used to visualize the distribution of categorical features and their relationships with other variables, like 'Segment' by 'Sales_Channel' and 'Category' by 'Country'.

# %% [markdown]
# ### Machine Learning Model Training and Evaluation
#
# This section focuses on building and evaluating machine learning models to predict 'Profit'.

# %% [markdown]
# #### Linear Regression Model
#
# We start with a simple Linear Regression model using 'Quantity' as the predictor for 'Profit'.

# %% [markdown]
# #### Model Evaluation Metrics
#
# Various metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared (R2) are used to evaluate the performance of the Linear Regression model.

# %% [markdown]
# #### Actual vs. Predicted Profit Visualization
#
# A scatter plot comparing actual vs. predicted profit values helps visualize the model's performance.

# %% [markdown]
# #### Decision Tree Regressor Model
#
# Given the low R-squared value of the Linear Regression model, a Decision Tree Regressor is explored as an alternative to predict 'Profit' using 'Quantity'.

# %% [markdown]
# Let's first ensure that `DecisionTreeRegressor` is imported.

# %% [markdown]
# Next, we will train and evaluate the Decision Tree model using the same 'Quantity' and 'Profit' data.

# %% [markdown]
# #### Decision Tree Model Evaluation Metrics
#
# We will evaluate the Decision Tree model using MAE, MSE, RMSE, and R-squared to compare its performance against the Linear Regression model.

# %% [markdown]
# ### Findings of the Analysis
#
# The initial analysis and Linear Regression model training revealed the following:
#
# *   **Sales, Profit, and Discount Distribution:** Histograms provided insights into the distribution of these key numerical features, showing their ranges and common values.
# *   **Relationships between Numerical Features:** Scatter plots between 'Sales' vs 'Profit' and 'Discount' vs 'Profit' indicated complex relationships, suggesting that simple linear dependencies might not fully capture the variance.
# *   **Categorical Feature Analysis:** Count plots for 'Segment' vs 'Sales_Channel' and 'Category' by 'Country' helped understand the distribution of categorical variables and potential influence on sales.
# *   **Linear Regression Model Performance:** When using 'Quantity' as the sole predictor for 'Profit' in a Linear Regression model, the model exhibited very poor performance:
#     *   **Mean Absolute Error (MAE):** 384.00
#     *   **Mean Squared Error (MSE):** 239252.49
#     *   **Root Mean Squared Error (RMSE):** 489.13
#     *   **R-squared (R2):** 0.00
#
#     The R-squared value of 0.00 indicates that 'Quantity' alone explains almost none of the variability in 'Profit', suggesting that a more sophisticated model or additional features are needed for better prediction. This has led to the exploration of a Decision Tree Regressor as an alternative.
